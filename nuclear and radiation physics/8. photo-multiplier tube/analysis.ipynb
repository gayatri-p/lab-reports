# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import pandas as pd

# %%
def straight_line(x, m, c): return m*x+c
def fit_line(xs, ys):
    popt = linregress(xs, ys)
    xFit = np.arange(min(xs), max(xs), 2e-4)
    label = f'For the best fit line (r-value = {popt.rvalue:.3f}):\nslope = ({popt.slope:.2e} ± {popt.stderr:.2e})' + f'\nintercept = ({popt.intercept:.2e} ± {popt.intercept_stderr:.2e})' 

    return xFit, straight_line(xFit, popt.slope, popt.intercept), (popt.slope, popt.intercept), (popt.stderr, popt.intercept_stderr), label

# %%
data1 = pd.read_excel('data.xlsx', sheet_name='gain')
plt.plot(data1['log V'], data1['log G'], 'ko', label='Data points')
xx, yy, fit, error, label = fit_line(data1['log V'], data1['log G'])
plt.plot(xx,yy, 'r--', linewidth=2, label='Linear Fit')
plt.legend()
plt.ylabel(r'$\log G$')
plt.xlabel(r'$\log V$')
plt.text(0.45,0.15,label, fontsize=10,transform=plt.gcf().transFigure)
plt.tight_layout()
# plt.savefig('images/gain.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
data1 = pd.read_excel('data.xlsx', sheet_name='spec')
plt.errorbar(data1['wavelength'], data1['sensitivity'], data1['sens_err'],  fmt='-ko', capsize=5, label='Data points')
plt.legend()
plt.ylabel(r'Sensitivity (A/W)')
plt.xlabel(r'Wavelength (nm)')
plt.tight_layout()
plt.savefig('images/spec.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
data1 = pd.read_excel('data.xlsx', sheet_name='dark')
plt.plot(data1['vpmt'], data1['ipmt'], '-ko', label='Data points')
plt.legend()
plt.ylabel(r'$I_{PMT}$ (mA)', fontsize=14)
plt.xlabel(r'$V_{PMT}$ (V)', fontsize=14)
plt.tight_layout()
# plt.savefig('images/dark.eps')
